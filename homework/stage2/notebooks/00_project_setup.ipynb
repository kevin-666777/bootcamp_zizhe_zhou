# %% [markdown]
# # Environment & Config Check
#
# This notebook verifies the Stage 02 Python environment, private configuration, and NumPy installation.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

print("Python version:", sys.version.split()[0])
print("Python executable:", sys.executable)
print("Project root:", PROJECT_ROOT)
# Out:
# Python version: 3.11.15
# Python executable: /Users/kevin/.conda/envs/fe-course/bin/python
# Project root: /Users/kevin/Desktop/NYU/bootcamp/bootcamp_zizhe_zhou/homework/stage2

# %%
import os
from dotenv import load_dotenv

load_dotenv(PROJECT_ROOT / ".env")
print("API_KEY present:", bool(os.getenv("API_KEY")))
print("DATA_DIR:", os.getenv("DATA_DIR"))
# Out:
# API_KEY present: True
# DATA_DIR: ./data

# %%
import sys

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import get_key, load_env

load_env()
print("Config helper check:", get_key("API_KEY") is not None)
# Out:
# Config helper check: True

# %%
import numpy as np

values = np.array([2, 4, 6])
print("Array:", values)
print("Array doubled:", values * 2)
print("Mean:", values.mean())
# Out:
# Array: [2 4 6]
# Array doubled: [ 4  8 12]
# Mean: 4.0

# %% [markdown]
# ## Result
#
# A successful run prints `API_KEY present: True`, confirms the reusable config helper, and displays the NumPy array operation. The key value itself is never printed.
