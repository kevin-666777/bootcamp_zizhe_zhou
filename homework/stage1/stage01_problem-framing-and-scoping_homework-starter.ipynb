# %% [markdown]
# # Homework Starter — Stage 01: Problem Framing & Scoping
# Use this notebook if you prefer to draft your scoping paragraph and memo inline, then copy to README.
# If you already created your repo structure, set `REPO_PATH` below accordingly and re-run the scaffold cell.

# %%
import pathlib

REPO_PATH = pathlib.Path.cwd()
for directory in ["data/raw", "data/processed", "src", "notebooks", "docs"]:
    (REPO_PATH / directory).mkdir(parents=True, exist_ok=True)

print(f"Project folders are ready in: {REPO_PATH.resolve()}")
print(f"Completed README: {(REPO_PATH / 'README.md').resolve()}")

# %% [markdown]
# ## Draft: Scoping Paragraph
# Stock prices can move sharply from one trading day to the next, making market risk difficult to summarize using only recent returns. This student project will explore whether historical price and volume data can be used to predict the next trading day's volatility for a selected stock or market index. A useful result would help explain when volatility is likely to rise or fall and provide a simple, reproducible example of a predictive data science workflow.
#
# The project is an educational prototype, not a production trading system. The primary stakeholder and reader is the course instructor, while the student is the main user building and evaluating the analysis. The useful answer is predictive: an estimate of next-day realized volatility, evaluated with MAE and RMSE against a recent rolling-volatility baseline. The deliverable will be a reproducible notebook or report with forecasts, diagnostic plots, and a plain-language explanation of assumptions and limitations; it will not be used as investment advice.

# %% [markdown]
# ## Stakeholder Artifact
# The selected stakeholder artifact is a markdown memo for the course instructor. See [`docs/stakeholder_memo.md`](docs/stakeholder_memo.md).
#
# The memo summarizes the classroom context, expected deliverables, assumptions, risks, and the decision rule for continuing to later project stages.
